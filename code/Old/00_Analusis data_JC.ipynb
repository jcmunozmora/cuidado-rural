# %% [markdown]
# # Análisis de datos de Proyectos cuidado
#
# Universidad EAFIT, 2025

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# Información proyectoPCS inicial
# Load the Excel file and specify the sheet name
file_path = "Informacion BID/Matriz propuestas trabajadas sobre TCR.xlsx"
py_ini = pd.read_excel(file_path, sheet_name="Información proyectoPCS inicial")

# Clean column names
py_ini.columns = py_ini.columns.str.replace('[^A-Za-z0-9]+', '_').str.strip()

# Display the cleaned column names
print(py_ini.columns)
# Out:
# Index(['No. Contrato', 'NombreProyecto', 'MacroRegion', 'SubregionPDET',
#        'Departamento', 'Municipio', 'Vereda', 'EEE', 'FechaInicio',
#        'FechaFinalizacion', 'Tipo de Beneficiario',
#        'TotalBeneficiariosDepartamento', 'MujeresBeneficiarias',
#        'HombresBeneficiarios', 'CampesinosHombres', 'CampesinasMujeres',
#        'NARP-Hombres', 'NARP-Mujeres', 'IndigenasHombres', 'IndigenasMujeres',
#        'AreaTematica', 'ProductoPrincipal1'],
#       dtype='object')

# %% [markdown]
# ## Estadísticas básicas de los proyectos productivos
#
# En esta sección exploramos los datos iniciales

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Create a figure and axes
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# List of variables to plot
variables = ['TotalBeneficiariosDepartamento', 'MujeresBeneficiarias', 'HombresBeneficiarios', 
             'CampesinosHombres', 'CampesinasMujeres', 'NARP-Hombres', 'NARP-Mujeres', 
             'IndigenasHombres', 'IndigenasMujeres']

# Plot each variable
for i, var in enumerate(variables):
    sns.histplot(py_ini[var], kde=True, ax=axes[i])
    axes[i].set_title(f'Distribution of {var}')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Frequency')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Select the relevant columns
selected_columns = py_ini[variables]

# Generate summary statistics
summary_stats = selected_columns.describe()

# Display the summary statistics
print(summary_stats)
# Out:
#        TotalBeneficiariosDepartamento  MujeresBeneficiarias  \
# count                       87.000000             87.000000
# mean                       176.827586             74.149425
# std                        309.830269            157.135368
# min                         65.000000              9.000000
# 25%                         73.000000             22.500000
# 50%                        100.000000             38.000000
# 75%                        149.000000             63.000000
# max                       2283.000000           1179.000000
#
#        HombresBeneficiarios  CampesinosHombres  CampesinasMujeres  \
# count             87.000000          87.000000          87.000000
# mean             102.678161          62.724138          39.287356
# std              155.708172          54.394915          44.357928
# min                0.000000           0.000000           0.000000
# 25%               50.500000          33.000000          18.000000
# 50%               65.000000          54.000000          24.000000
# 75%               91.000000          81.500000          44.500000
# max             1104.000000         395.000000         288.000000
#
#        NARP-Hombres  NARP-Mujeres  IndigenasHombres  IndigenasMujeres
# count     87.000000     87.000000         87.000000         87.000000
# mean       9.298851      7.275862         29.666667         27.896552
# std       46.395197     32.601073        154.788278        157.068496
# min        0.000000      0.000000          0.000000          0.000000
# 25%        0.000000      0.000000          0.000000          0.000000
# 50%        0.000000      0.000000          0.000000          0.000000
# 75%        0.000000      0.000000          2.000000          1.000000
# max      307.000000    211.000000       1104.000000       1179.000000

# %%
# List of categorical variables to plot
categorical_vars = ['MacroRegion', 'Departamento', 'Tipo_de_Beneficiario', 'AreaTematica', 'ProductoPrincipal1']

# Verificar que las variables categóricas existen en el DataFrame
categorical_vars = [var for var in categorical_vars if var in py_ini.columns]

# Set the style for the plots
sns.set(style="whitegrid")

# Create a figure and axes
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15))  # Ajusta el número de filas y columnas según sea necesario

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot each categorical variable
for i, var in enumerate(categorical_vars):
    sns.countplot(data=py_ini, x=var, ax=axes[i], palette="viridis")
    axes[i].set_title(f'Count of {var}')
    axes[i].set_xlabel(var)
    axes[i].set_ylabel('Count')
    axes[i].tick_params(axis='x', rotation=90)

# Eliminar cualquier subplot vacío
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/684958726.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=py_ini, x=var, ax=axes[i], palette="viridis")
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/684958726.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=py_ini, x=var, ax=axes[i], palette="viridis")
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/684958726.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=py_ini, x=var, ax=axes[i], palette="viridis")
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/684958726.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=py_ini, x=var, ax=axes[i], palette="viridis")

# %% [markdown]
# Ahora vamos a ver un poco las distribuciones espaciales

# %%
# Load the shapefiles
dpto_shapefile = gpd.read_file("02_Data/Colombia_Division/COL_adm1.shp")
mpio_shapefile = gpd.read_file("02_Data/Colombia_Division/COL_adm2.shp")

# Plot the shapefiles
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
dpto_shapefile.plot(ax=ax, color='white', edgecolor='black')
mpio_shapefile.plot(ax=ax, color='blue', alpha=0.5)

# Display the 'NMG' column of the dpto_shapefile dataframe
print(dpto_shapefile[['NAME_1']])
# Out:
#                       NAME_1
# 0                   Amazonas
# 1                  Antioquia
# 2                     Arauca
# 3                  Atlßntico
# 4                    BolÝvar
# 5                     Boyacß
# 6                     Caldas
# 7                    Caquetß
# 8                   Casanare
# 9                      Cauca
# 10                     Cesar
# 11                     Choc¾
# 12                   C¾rdoba
# 13              Cundinamarca
# 14                   GuainÝa
# 15                  Guaviare
# 16                     Huila
# 17                La Guajira
# 18                 Magdalena
# 19                      Meta
# 20                    Nari±o
# 21        Norte de Santander
# 22                  Putumayo
# 23                   QuindÝo
# 24                 Risaralda
# 25  San AndrÚs y Providencia
# 26                 Santander
# 27                     Sucre
# 28                    Tolima
# 29           Valle del Cauca
# 30                    VaupÚs
# 31                   Vichada

# %%
# Define the mapping of incorrect names to correct names
name_corrections = {
    'Sucre' : 'SUCRE',
    'Antioquia' : 'ANTIOQUIA',
    'Putumayo' : 'PUTUMAYO',
    'Cauca' : 'CAUCA',
    'Nari±o' : 'NARIÑO',
    'C¾rdoba' : 'CÓRDOBA',
    'Guaviare' : 'GUAVIARE',
    'Meta' : 'META',
    'Tolima' : 'TOLIMA',
    'Caquetß' : 'CAQUETA',
    'BolÝvar' : 'BOLIVAR',
    'Arauca': 'ARAUCA',
    'Cesar': 'CESAR'
}

# Apply the corrections to the NAME_2 column
dpto_shapefile['NAME_1'] = dpto_shapefile['NAME_1'].replace(name_corrections)

# Display the corrected names
print(dpto_shapefile['NAME_1'].unique())
# Out:
# ['Amazonas' 'ANTIOQUIA' 'ARAUCA' 'Atlßntico' 'BOLIVAR' 'Boyacß' 'Caldas'
#  'CAQUETA' 'Casanare' 'CAUCA' 'CESAR' 'Choc¾' 'CÓRDOBA' 'Cundinamarca'
#  'GuainÝa' 'GUAVIARE' 'Huila' 'La Guajira' 'Magdalena' 'META' 'NARIÑO'
#  'Norte de Santander' 'PUTUMAYO' 'QuindÝo' 'Risaralda'
#  'San AndrÚs y Providencia' 'Santander' 'SUCRE' 'TOLIMA' 'Valle del Cauca'
#  'VaupÚs' 'Vichada']

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Merge the shapefile with the project data
merged_data = dpto_shapefile.merge(py_ini, left_on='NAME_1', right_on='Departamento')

# Convert to Web Mercator projection (EPSG:3857) for compatibility with contextily
merged_data = merged_data.to_crs(epsg=3857)

# Plot the map with TotalBeneficiariosDepartamento
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_data.plot(column='TotalBeneficiariosDepartamento', ax=ax, legend=True,
                 legend_kwds={'label': "Total Beneficiaries by Department",
                              'orientation': "horizontal"})

# Add background map
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)


plt.title('Total Beneficiaries by Department')
plt.show()

# %%
# Filter the data
filtered_data = py_ini[(py_ini['ProductoPrincipal1'] == 'CAFÉ') & (py_ini['Tipo de Beneficiario'] == 'CAMPESINO')]

# Get the number of such projects
num_projects = filtered_data.shape[0]
print(f"Number of projects with ProductoPrincipal1 as 'CAFÉ' and Tipo de Beneficiario as 'CAMPESINO': {num_projects}")

# Merge the filtered data with the shapefile
merged_filtered_data = dpto_shapefile.merge(filtered_data, left_on='NAME_1', right_on='Departamento')

# Convert to Web Mercator projection (EPSG:3857) for compatibility with contextily
merged_filtered_data = merged_filtered_data.to_crs(epsg=3857)

# Plot the map with TotalBeneficiariosDepartamento
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_filtered_data.plot(column='TotalBeneficiariosDepartamento', ax=ax, legend=True,
                          legend_kwds={'label': "Total Beneficiaries by Department",
                                       'orientation': "horizontal"})

plt.title('Total Beneficiaries by Department for CAFÉ and CAMPESINO')
plt.show()
# Out:
# Number of projects with ProductoPrincipal1 as 'CAFÉ' and Tipo de Beneficiario as 'CAMPESINO': 18

# %%
# Filter the data for 'CAMPESINO' beneficiaries
campesino_data = py_ini[py_ini['Tipo de Beneficiario'] == 'CAMPESINO']

# Group by 'ProductoPrincipal1' and sum the 'TotalBeneficiariosDepartamento'
beneficiaries_by_product = campesino_data.groupby('ProductoPrincipal1')['TotalBeneficiariosDepartamento'].sum().reset_index()

# Plot the composition of 'ProductoPrincipal1' for 'CAMPESINO' beneficiaries
plt.figure(figsize=(10, 6))
sns.barplot(data=beneficiaries_by_product, x='ProductoPrincipal1', y='TotalBeneficiariosDepartamento', palette="viridis")
plt.title('Total Beneficiaries by ProductoPrincipal1 for CAMPESINO Beneficiaries')
plt.xlabel('ProductoPrincipal1')
plt.ylabel('Total Beneficiaries')
plt.xticks(rotation=90)
plt.show()
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/2268113654.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=beneficiaries_by_product, x='ProductoPrincipal1', y='TotalBeneficiariosDepartamento', palette="viridis")

# %%
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/3919292330.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=campesino_data, x='ProductoPrincipal1', palette="viridis")

# %%
# Distribution plot for CampesinasMujeres
plt.figure(figsize=(10, 6))
sns.histplot(py_ini['CampesinasMujeres'], kde=True, color='purple')
plt.title('Distribution of Campesinas Mujeres')
plt.xlabel('Campesinas Mujeres')
plt.ylabel('Frequency')
plt.show()

# Merge the shapefile with the project data for CampesinasMujeres
merged_data_mujeres = dpto_shapefile.merge(py_ini, left_on='NAME_1', right_on='Departamento')

# Convert to Web Mercator projection (EPSG:3857) for compatibility with contextily
merged_data_mujeres = merged_data_mujeres.to_crs(epsg=3857)

# Plot the map with CampesinasMujeres
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_data_mujeres.plot(column='CampesinasMujeres', ax=ax, legend=True,
                         legend_kwds={'label': "Campesinas Mujeres by Department",
                                      'orientation': "horizontal"},
                         cmap='Purples')

plt.title('Campesinas Mujeres by Department')
plt.show()

# %% [markdown]
# # Propuestas Activas evaluadas
#
# Propuestas evaluadas de los datos.

# %%
# Load the second row in the Excel file and specify the sheet name
prop_evl = pd.read_excel(file_path, sheet_name="Propuestas activos evaluadas ",skiprows=[0])

# Clean column names
prop_evl.columns = prop_evl.columns.str.replace('[^A-Za-z0-9]+', '_').str.strip()

# Display the cleaned column names
prop_evl.head()
print(prop_evl.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Hombres', 'Mujeres', 'Unnamed: 4',
#        'Municipio', 'Departamento', 'Doméstica', 'Dispositivos de apoyo',
#        'Productiva', 'Infraestructura'],
#       dtype='object')

# %%
# Generate summary statistics for prop_evl
summary_stats_prop_evl = prop_evl.describe(include='all')

# Display the summary statistics
print(summary_stats_prop_evl)
# Out:
#        proy_code concepto      Hombres      Mujeres  poblacion  Municipio  \
# count         79       79    64.000000    67.000000         79         79
# unique        79        2          NaN          NaN          8         54
# top     039-2022   viable          NaN          NaN  CAMPESINO  CHAPARRAL
# freq           1       64          NaN          NaN         53          8
# mean         NaN      NaN   202.906250   173.134328        NaN        NaN
# std          NaN      NaN   217.085216   203.153688        NaN        NaN
# min          NaN      NaN    22.000000     8.000000        NaN        NaN
# 25%          NaN      NaN    99.750000    77.500000        NaN        NaN
# 50%          NaN      NaN   151.500000   121.000000        NaN        NaN
# 75%          NaN      NaN   226.500000   198.000000        NaN        NaN
# max          NaN      NaN  1580.000000  1440.000000        NaN        NaN
#
#        Departamento  Doméstica  Dispositivos de apoyo  Productiva  \
# count            79  79.000000              79.000000   79.000000
# unique           13        NaN                    NaN         NaN
# top          TOLIMA        NaN                    NaN         NaN
# freq             17        NaN                    NaN         NaN
# mean            NaN   0.810127               0.151899    0.379747
# std             NaN   0.394707               0.361216    0.488425
# min             NaN   0.000000               0.000000    0.000000
# 25%             NaN   1.000000               0.000000    0.000000
# 50%             NaN   1.000000               0.000000    0.000000
# 75%             NaN   1.000000               0.000000    1.000000
# max             NaN   1.000000               1.000000    1.000000
#
#         Infraestructura
# count         79.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           0.202532
# std            0.404454
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
# Rename the columns
prop_evl.rename(columns={
    'Unnamed: 0': 'proy_code',
    'Unnamed: 1': 'concepto',
    'Hombres': 'Hombres',
    'Mujeres': 'Mujeres',
    'Unnamed: 4': 'poblacion'
}, inplace=True)

# Display the renamed columns
print(prop_evl.columns)
# Out:
# Index(['proy_code', 'concepto', 'Hombres', 'Mujeres', 'poblacion', 'Municipio',
#        'Departamento', 'Doméstica', 'Dispositivos de apoyo', 'Productiva',
#        'Infraestructura'],
#       dtype='object')

# %%
# Group by 'concepto' and count the occurrences
concepto_table = prop_evl.groupby('concepto').size().reset_index(name='count')



# Display the table
print(concepto_table)
print(problacion_table)
# Out:
#     concepto  count
# 0  no viable     15
# 1     viable     64
#                  poblacion  count
# 0                CAMPESINO     53
# 1       CAMPESINO-INDÍGENA      5
# 2  CAMPESINO-INDÍGENA-NARP      8
# 3           CAMPESINO-NARP      4
# 4                 INDIGENA      1
# 5                 INDÍGENA      6
# 6         INDÍGENA-NARP         1
# 7                     NARP      1

# %%
# Filter the data to include only viable proposals
viable_proposals = prop_evl[prop_evl['concepto'] == 'viable']

# Group by 'poblacion' and count the occurrences
problacion_table = viable_proposals.groupby('poblacion').size().reset_index(name='count')

# Display the table
print(problacion_table)
# Out:
#                  poblacion  count
# 0                CAMPESINO     46
# 1       CAMPESINO-INDÍGENA      5
# 2  CAMPESINO-INDÍGENA-NARP      4
# 3           CAMPESINO-NARP      2
# 4                 INDÍGENA      5
# 5         INDÍGENA-NARP         1
# 6                     NARP      1

# %%
# Replace NaN values with 0 for summation
prop_evl['Doméstica'] = prop_evl['Doméstica'].fillna(0)
prop_evl['Dispositivos de apoyo'] = prop_evl['Dispositivos de apoyo'].fillna(0)
prop_evl['Productiva'] = prop_evl['Productiva'].fillna(0)
prop_evl['Infraestructura'] = prop_evl['Infraestructura'].fillna(0)

# Convert columns to binary (1 if not NaN, 0 if NaN)
prop_evl['Doméstica'] = prop_evl['Doméstica'].apply(lambda x: 1 if x != 0 else 0)
prop_evl['Dispositivos de apoyo'] = prop_evl['Dispositivos de apoyo'].apply(lambda x: 1 if x != 0 else 0)
prop_evl['Productiva'] = prop_evl['Productiva'].apply(lambda x: 1 if x != 0 else 0)
prop_evl['Infraestructura'] = prop_evl['Infraestructura'].apply(lambda x: 1 if x != 0 else 0)

# Sum the values for each dimension
dimension_sums = prop_evl[['Doméstica', 'Dispositivos de apoyo', 'Productiva', 'Infraestructura']].sum()

# Plot the sums
plt.figure(figsize=(10, 6))
sns.barplot(x=dimension_sums.index, y=dimension_sums.values, palette="viridis")
plt.title('Sum of Each Dimension')
plt.xlabel('Dimension')
plt.ylabel('Sum')
plt.show()
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/3880814174.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=dimension_sums.index, y=dimension_sums.values, palette="viridis")

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Create a figure for the plot
plt.figure(figsize=(12, 8))

# Plot the distribution of "Población"
sns.countplot(data=prop_evl, x='poblacion', palette="viridis")

# Set plot title and labels
plt.title('Distribution of Población')
plt.xlabel('Población')
plt.ylabel('Count')
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/2393309886.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=prop_evl, x='poblacion', palette="viridis")

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Melt the dataframe to long format for easier plotting
melted_prop_evl = prop_evl.melt(id_vars=['poblacion'], value_vars=['Doméstica', 'Dispositivos de apoyo', 'Productiva', 'Infraestructura'], 
                                var_name='Dimension', value_name='Value')

# Create the grouped bar plot
plt.figure(figsize=(12, 8))
sns.barplot(data=melted_prop_evl, x='poblacion', y='Value', hue='Dimension', palette="viridis")

# Set plot title and labels
plt.title('Cross Graph of Poblacion and Different Dimensions')
plt.xlabel('Poblacion')
plt.ylabel('Value')
plt.xticks(rotation=90)
plt.legend(title='Dimension')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a pivot table to cross-tabulate 'concepto' and 'poblacion'
cross_section = pd.pivot_table(prop_evl, values='proy_code', index='concepto', columns='poblacion', aggfunc='count', fill_value=0)

# Display the cross-section
print(cross_section)
# Out:
# poblacion  CAMPESINO  CAMPESINO-INDÍGENA  CAMPESINO-INDÍGENA-NARP  \
# concepto
# no viable          7                   0                        4
# viable            46                   5                        4
#
# poblacion  CAMPESINO-NARP  INDIGENA  INDÍGENA  INDÍGENA-NARP     NARP
# concepto
# no viable               2         1         1                 0     0
# viable                  2         0         5                 1     1

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Create a figure for the plot
plt.figure(figsize=(12, 8))

# Plot the distribution of "concepto"
sns.countplot(data=prop_evl, x='concepto', palette="viridis")

# Set plot title and labels
plt.title('Distribution of Concepto')
plt.xlabel('Concepto')
plt.ylabel('Count')
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/288650722.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=prop_evl, x='concepto', palette="viridis")

# %%
# Filter the data to include only viable proposals
viable_proposals = prop_evl[prop_evl['concepto'] == 'viable']

# Group by 'Departamento' and count the number of proposals
viable_proposals_count = viable_proposals.groupby('Departamento').size().reset_index(name='viable_proposals_count')

# Merge the grouped data with the department shapefile
merged_viable_data = dpto_shapefile.merge(viable_proposals_count, left_on='NAME_1', right_on='Departamento', how='left')

# Fill NaN values with 0 (for departments with no viable proposals)
merged_viable_data['viable_proposals_count'] = merged_viable_data['viable_proposals_count'].fillna(0)

# Plot the map
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_viable_data.plot(column='viable_proposals_count', ax=ax, legend=True,
                        legend_kwds={'label': "Number of Viable Proposals by Department",
                                     'orientation': "horizontal"},
                        cmap='OrRd')

plt.title('Number of Viable Proposals by Department')
plt.show()

# %%
# Filter the data to include only non-viable proposals
non_viable_proposals = prop_evl[prop_evl['concepto'] != 'viable']

# Group by 'Departamento' and count the number of non-viable proposals
non_viable_proposals_count = non_viable_proposals.groupby('Departamento').size().reset_index(name='non_viable_proposals_count')

# Merge the grouped data with the department shapefile
merged_non_viable_data = dpto_shapefile.merge(non_viable_proposals_count, left_on='NAME_1', right_on='Departamento', how='left')

# Fill NaN values with 0 (for departments with no non-viable proposals)
merged_non_viable_data['non_viable_proposals_count'] = merged_non_viable_data['non_viable_proposals_count'].fillna(0)

# Plot the map
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_non_viable_data.plot(column='non_viable_proposals_count', ax=ax, legend=True,
                            legend_kwds={'label': "Number of Non-Viable Proposals by Department",
                                         'orientation': "horizontal"},
                            cmap='OrRd')

plt.title('Number of Non-Viable Proposals by Department')
plt.show()

# %% [markdown]
# Ahora vamos a comparar el total de proyectos con la propuesta evaluada

# %%
# Merge py_ini and prop_evl on 'No. Contrato' and 'proy_code'
merged_projects = py_ini.merge(prop_evl, left_on='No. Contrato', right_on='proy_code', how='inner')

# %%
# Group by 'ProductoPrincipal1' and 'concepto' and count the occurrences
grouped_data = merged_projects.groupby(['ProductoPrincipal1', 'concepto']).size().reset_index(name='count')

# Set the style for the plots
sns.set(style="whitegrid")

# Create a figure for the plot
plt.figure(figsize=(12, 8))

# Create the bar plot
sns.barplot(data=grouped_data, x='ProductoPrincipal1', y='count', hue='concepto', palette="viridis")

# Set plot title and labels
plt.title('Count of Proposals by ProductoPrincipal1 and Concepto')
plt.xlabel('ProductoPrincipal1')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Concepto')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Proyectos activos
#
# Ahora vamos a ver información de los proyectos activos.

# %%
prop_act= pd.read_excel(file_path, sheet_name="Propuestas activos TCR a nov. ")
prop_act.columns = prop_act.columns.str.replace('[^A-Za-z0-9]+', '_').str.strip()
print(prop_act.columns)
# Out:
# Index(['NumeroContrato', 'Activos a 15 noviembre', 'Departamento', 'Municipio',
#        'Tipo de Beneficiario', 'TotalBeneficiariosDepartamento',
#        'MujeresBeneficiarias', 'HombresBeneficiarios'],
#       dtype='object')

# %%
# Generate summary statistics for prop_act
summary_stats_prop_act = prop_act.describe(include='all')

# Display the summary statistics
print(summary_stats_prop_act)
# Out:
#        NumeroContrato Activos a 15 noviembre Departamento  Municipio  \
# count              80                     80           80         80
# unique             80                     77           13         55
# top          039-2022    estufa ecoeficiente       TOLIMA  CHAPARRAL
# freq                1                      3           17          8
# mean              NaN                    NaN          NaN        NaN
# std               NaN                    NaN          NaN        NaN
# min               NaN                    NaN          NaN        NaN
# 25%               NaN                    NaN          NaN        NaN
# 50%               NaN                    NaN          NaN        NaN
# 75%               NaN                    NaN          NaN        NaN
# max               NaN                    NaN          NaN        NaN
#
#        Tipo de Beneficiario  TotalBeneficiariosDepartamento  \
# count                    80                       80.000000
# unique                    8                             NaN
# top               CAMPESINO                             NaN
# freq                     54                             NaN
# mean                    NaN                      154.325000
# std                     NaN                      217.764463
# min                     NaN                       65.000000
# 25%                     NaN                       73.000000
# 50%                     NaN                      100.000000
# 75%                     NaN                      140.750000
# max                     NaN                     1819.000000
#
#         MujeresBeneficiarias  HombresBeneficiarios
# count              80.000000             80.000000
# unique                   NaN                   NaN
# top                      NaN                   NaN
# freq                     NaN                   NaN
# mean               61.800000             92.525000
# std               105.809884            115.804831
# min                 9.000000              0.000000
# 25%                22.000000             51.000000
# 50%                36.000000             65.000000
# 75%                59.750000             87.000000
# max               883.000000            936.000000

# %%
from wordcloud import WordCloud

# Combine all text in the 'Activos a 15 noviembre' column
text = " ".join(prop_act['Activos a 15 noviembre'])

# Create a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Activos a 15 noviembre')
plt.show()

# %%
# Set the style for the plots
sns.set(style="whitegrid")

# Create a figure for the plot
plt.figure(figsize=(12, 8))

# Plot the distribution of "Tipo de Beneficiario"
sns.countplot(data=prop_act, x='Tipo de Beneficiario', palette="viridis")

# Set plot title and labels
plt.title('Distribution of Tipo de Beneficiario')
plt.xlabel('Tipo de Beneficiario')
plt.ylabel('Count')
plt.xticks(rotation=90)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/2616699177.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=prop_act, x='Tipo de Beneficiario', palette="viridis")

# %%
# Merge the shapefile with the project data for MujeresBeneficiarias
merged_data_mujeres = dpto_shapefile.merge(py_ini, left_on='NAME_1', right_on='Departamento')

# Convert to Web Mercator projection (EPSG:3857) for compatibility with contextily
merged_data_mujeres = merged_data_mujeres.to_crs(epsg=3857)

# Plot the map with MujeresBeneficiarias
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_data_mujeres.plot(column='MujeresBeneficiarias', ax=ax, legend=True,
                         legend_kwds={'label': "Mujeres Beneficiarias by Department",
                                      'orientation': "horizontal"},
                         cmap='Purples')

plt.title('Mujeres Beneficiarias by Department')
plt.show()

# %% [markdown]
# # Propuesta de muestreo
#
# Quedarnos solo con los proyecto:
#
# Criterio de selección:
# - Proyectos productivos cuyas solicitudes para apoyo del cuidado fueron viables
# - Proyectos que involucran a al menos 50 personas
# - Campesinos
#
# Qué necesitamos? necesitamos asignación aleatoria.
# - Tratamiento y control
# - Power calculation (tamaño de la muestra)

# %%
# Merge prop_evl and prop_act on 'NumeroContrato'
merged_proposals = prop_evl.merge(prop_act, left_on='proy_code', right_on='NumeroContrato', how='inner')

# Display the merged dataframe
print(merged_proposals.head())
# Out:
#   proy_code concepto  Hombres  Mujeres           poblacion  \
# 0  039-2022   viable    112.0    156.0           CAMPESINO
# 1  041-2022   viable    198.0    236.0           CAMPESINO
# 2  042-2022   viable     90.0    240.0  CAMPESINO-INDÍGENA
# 3  045-2022   viable     31.0     94.0      CAMPESINO-NARP
# 4  046-2022   viable    161.0    149.0           CAMPESINO
#
#           Municipio_x Departamento_x  Doméstica  Dispositivos de apoyo  \
# 0               ATACO         TOLIMA          1                      0
# 1            PLANADAS         TOLIMA          1                      0
# 2           CHAPARRAL         TOLIMA          1                      0
# 3  MERCADERES y PATÍA          CAUCA          1                      0
# 4             BALBOA           CAUCA          1                      1
#
#    Productiva  Infraestructura NumeroContrato  \
# 0           0                1       039-2022
# 1           0                1       041-2022
# 2           0                0       042-2022
# 3           1                1       045-2022
# 4           1                0       046-2022
#
#                               Activos a 15 noviembre Departamento_y  \
# 0  Lavadora, Refrigerador, Procesador de alimento...         TOLIMA
# 1  Lavadora, Refrigerador, Estufas ecológicas o e...         TOLIMA
# 2                             Refrigerador, lavadora         TOLIMA
# 3  estufas ecoeficientes leña, lavadoras, molinos...          CAUCA
# 4  estufa ecoeficiente, estufa eléctrica, molino ...          CAUCA
#
#           Municipio_y Tipo de Beneficiario  TotalBeneficiariosDepartamento  \
# 0               ATACO            CAMPESINO                              67
# 1            PLANADAS            CAMPESINO                             109
# 2           CHAPARRAL   CAMPESINO-INDÍGENA                              70
# 3  MERCADERES y PATÍA       CAMPESINO-NARP                              95
# 4             BALBOA             CAMPESINO                              96
#
#    MujeresBeneficiarias  HombresBeneficiarios
# 0                    12                    55
# 1                    36                    73
# 2                    19                    51
# 3                    62                    33
# 4                    28                    68

# %%
from tabulate import tabulate

# Filter the merged_proposals dataframe to include only viable proposals
viable_merged_proposals = merged_proposals[merged_proposals['concepto'] == 'viable']

# Display the filtered dataframe in a tabulated format
print(tabulate(viable_merged_proposals, headers='keys', tablefmt='psql'))
# Out:
# +----+-------------+------------+-----------+-----------+-------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-------------+-------------------------+--------------+-------------------+------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+----------------------------------+------------------------+------------------------+
# |    | proy_code   | concepto   |   Hombres |   Mujeres | poblacion               | Municipio_x                                                                                                                                             | Departamento_x   |   Doméstica |   Dispositivos de apoyo |   Productiva |   Infraestructura | NumeroContrato   | Activos a 15 noviembre                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            | Departamento_y   | Municipio_y                                                                                                                                             | Tipo de Beneficiario    |   TotalBeneficiariosDepartamento |   MujeresBeneficiarias |   HombresBeneficiarios |
# |----+-------------+------------+-----------+-----------+-------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-------------+-------------------------+--------------+-------------------+------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+----------------------------------+------------------------+------------------------|
# |  0 | 039-2022    | viable     |       112 |       156 | CAMPESINO               | ATACO                                                                                                                                                   | TOLIMA           |           1 |                       0 |            0 |                 1 | 039-2022         | Lavadora, Refrigerador, Procesador de alimentos, Dotación de espacios para uso de TICs                                                                                                                                                                                                                                                                                                                                                                                                                                            | TOLIMA           | ATACO                                                                                                                                                   | CAMPESINO               |                               67 |                     12 |                     55 |
# |  1 | 041-2022    | viable     |       198 |       236 | CAMPESINO               | PLANADAS                                                                                                                                                | TOLIMA           |           1 |                       0 |            0 |                 1 | 041-2022         | Lavadora, Refrigerador, Estufas ecológicas o ecoeficientes, procesador de alimentos, molino eléctrico, dotación espacio uso de tics                                                                                                                                                                                                                                                                                                                                                                                               | TOLIMA           | PLANADAS                                                                                                                                                | CAMPESINO               |                              109 |                     36 |                     73 |
# |  2 | 042-2022    | viable     |        90 |       240 | CAMPESINO-INDÍGENA      | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 042-2022         | Refrigerador, lavadora                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO-INDÍGENA      |                               70 |                     19 |                     51 |
# |  3 | 045-2022    | viable     |        31 |        94 | CAMPESINO-NARP          | MERCADERES y PATÍA                                                                                                                                      | CAUCA            |           1 |                       0 |            1 |                 1 | 045-2022         | estufas ecoeficientes leña, lavadoras, molinos manuales, licuadoras, picapasto, neveras, congeladores, bicicleta, motobomba, electrobomba, tanques de agua, adecuación cocina comunitaria                                                                                                                                                                                                                                                                                                                                         | CAUCA            | MERCADERES y PATÍA                                                                                                                                      | CAMPESINO-NARP          |                               95 |                     62 |                     33 |
# |  4 | 046-2022    | viable     |       161 |       149 | CAMPESINO               | BALBOA                                                                                                                                                  | CAUCA            |           1 |                       1 |            1 |                 0 | 046-2022         | estufa ecoeficiente, estufa eléctrica, molino eléctrico, utencilios de cocina, olla arrocera, juego de ollas, filtro de agua, freidora, nevera, lavadora, juegos didácticos para niños, escalera de 6 pasos, bastón, caminador, bicicleta estática, moto sierra pequeña, estacionaria, guadaña, juego de llaves, kit cuidado huerta casera, bugui manual, bomba de fumigar, manguera docil, malla cuidado de aves, herramientas de trabajo en finca, materiales cuidado fuentes de agua, tanque de almacenamiento de agua         | CAUCA            | BALBOA                                                                                                                                                  | CAMPESINO               |                               96 |                     28 |                     68 |
# |  5 | 047-2022    | viable     |        47 |        22 | CAMPESINO               | SAN JOSÉ DE FRAGUA                                                                                                                                      | CAQUETÁ          |           1 |                       0 |            0 |                 0 | 047-2022         | estufa ecoeficiente movil de leña, transporte y adecuación del lugar para las estufas                                                                                                                                                                                                                                                                                                                                                                                                                                             | CAQUETÁ          | SAN JOSÉ DE FRAGUA                                                                                                                                      | CAMPESINO               |                               69 |                     18 |                     51 |
# |  6 | 048-2022    | viable     |       103 |       104 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 048-2022         | Lavadoras, neveras, licuadoras,                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                              100 |                     23 |                     77 |
# |  7 | 049-2022    | viable     |        94 |        90 | CAMPESINO               | MORALES                                                                                                                                                 | CAUCA            |           1 |                       1 |            1 |                 1 | 049-2022         | estufa ecoeficiente, estifas a gas, lavadoras, molinos manual, molino eléctrico, olla a presión, licuadora, batidora, picapasto, nevera, congeladores, trituradores, silla de ruedas, bicicleta, caballo, estacionaria, unidad sanitaria adecuación, tanque de agua                                                                                                                                                                                                                                                               | CAUCA            | MORALES                                                                                                                                                 | CAMPESINO               |                               65 |                     36 |                     29 |
# |  8 | 051-2022    | viable     |       103 |       102 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 051-2022         | Lavadoras, nevera, licuadoras, freidora, horno eléctrico                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                               84 |                     16 |                     68 |
# |  9 | 054-2022    | viable     |       115 |       126 | CAMPESINO               | EL ROSARIO                                                                                                                                              | NARIÑO           |           1 |                       0 |            1 |                 0 | 054-2022         | estufas ecoeficientes, lavadoras, neveras, estufas a gas, refrigerador, molino eléctrico, licuadoras, computador                                                                                                                                                                                                                                                                                                                                                                                                                  | NARIÑO           | EL ROSARIO                                                                                                                                              | CAMPESINO               |                               73 |                     23 |                     50 |
# | 10 | 100-2022    | viable     |       164 |       147 | CAMPESINO-INDÍGENA      | PLANADAS                                                                                                                                                | TOLIMA           |           1 |                       0 |            0 |                 0 | 100-2022         | estufa ecoeficiente, lavadora, refrigerador                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | TOLIMA           | PLANADAS                                                                                                                                                | CAMPESINO-INDÍGENA      |                               67 |                      9 |                     58 |
# | 13 | 108-2022    | viable     |      1580 |      1440 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 108-2022         | olla pitadora, licuadora                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                              683 |                    288 |                    395 |
# | 14 | 110-2022    | viable     |       204 |        80 | CAMPESINO               | OVEJAS                                                                                                                                                  | SUCRE            |           1 |                       0 |            1 |                 0 | 110-2022         | estufa a gas, cilindro de gas, estufa eléctrica, molinos eléctricos, lavadoras, regriferadores, licuadoras, tanques de almacenamiento de agua, guadañas                                                                                                                                                                                                                                                                                                                                                                           | SUCRE            | OVEJAS                                                                                                                                                  | CAMPESINO               |                               71 |                     20 |                     51 |
# | 15 | 111-2022    | viable     |        53 |        55 | CAMPESINO               | CHIGORODO, MUTATA, APARTADO, TURBO                                                                                                                      | ANTIOQUIA        |           1 |                       1 |            1 |                 0 | 111-2022         | estufa ecoeficiente, refrigerador, procesador de alimentos, molino, lavadora, audífono, bordón, caminador, silla de ruedas, moto bomba, bicicleta, congelador, tanque almacenamiento agua, moto carguero                                                                                                                                                                                                                                                                                                                          | ANTIOQUIA        | CHIGORODO, MUTATA, APARTADO, TURBO                                                                                                                      | CAMPESINO               |                               71 |                     18 |                     53 |
# | 17 | 113-2022    | viable     |       165 |        95 | CAMPESINO-INDÍGENA-NARP | CAJIBÍO-MORALES                                                                                                                                         | CAUCA            |           1 |                       0 |            0 |                 0 | 113-2022         | estufa a gas propano, lavadora, nevera, congelador, arrocera, licuadora, freidora                                                                                                                                                                                                                                                                                                                                                                                                                                                 | CAUCA            | CAJIBÍO-MORALES                                                                                                                                         | CAMPESINO-INDÍGENA-NARP |                               77 |                     27 |                     50 |
# | 18 | 114-2022    | viable     |       226 |       228 | CAMPESINO               | PLANADAS                                                                                                                                                | TOLIMA           |           1 |                       0 |            0 |                 0 | 114-2022         | estufa ecoeficiente, lavadora, nevera, estufa a gas                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | TOLIMA           | PLANADAS                                                                                                                                                | CAMPESINO               |                              101 |                     17 |                     84 |
# | 19 | 115-2022    | viable     |       271 |       237 | CAMPESINO-NARP          | OVEJAS                                                                                                                                                  | SUCRE            |           1 |                       0 |            1 |                 0 | 115-2022         | lavadora, estufa a gas, estufa eléctrica, cilindro, neveras, olla a presión, licuadora, molino eléctrico para carne, molino eléctrico para granos, tanque almacenamiento agua, congelador, horno eléctrico                                                                                                                                                                                                                                                                                                                        | SUCRE            | OVEJAS                                                                                                                                                  | CAMPESINO-NARP          |                              170 |                     43 |                    127 |
# | 20 | 120-2022    | viable     |       296 |       280 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 120-2022         | estufa ecoeficiente, lavadoras                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                               97 |                     26 |                     71 |
# | 22 | 122-2022    | viable     |       190 |       160 | CAMPESINO-INDÍGENA-NARP | TIERRALTA                                                                                                                                               | CÓRDOBA          |           1 |                       0 |            1 |                 1 | 122-2022         | estufa ecoeficiente, guadaña, pitadora, canoa, docación CREA, Dotación espacio adulto mayor, dotación comedor escolar                                                                                                                                                                                                                                                                                                                                                                                                             | CÓRDOBA          | TIERRALTA                                                                                                                                               | CAMPESINO-INDÍGENA-NARP |                              335 |                    115 |                    220 |
# | 24 | 127-2022    | viable     |       100 |        86 | CAMPESINO               | SAN JUAN NEPOMUCENO                                                                                                                                     | BOLÍVAR          |           1 |                       1 |            1 |                 0 | 127-2022         | estufa ecoeficiente, lavadora, audífono, silla de ruedas, paneles solares, motobomba, guadañas, refrigeradores, picapasto                                                                                                                                                                                                                                                                                                                                                                                                         | BOLÍVAR          | SAN JUAN NEPOMUCENO                                                                                                                                     | CAMPESINO               |                               65 |                     22 |                     43 |
# | 25 | 128-2022    | viable     |       100 |       101 | CAMPESINO               | TAME                                                                                                                                                    | ARAUCA           |           1 |                       0 |            0 |                 1 | 128-2022         | molino eléctrico, estufas 4 puestos con horno, congelador, neveras, lavadoras, horno panadería, estufa industrial, sillas de ruedas, muletas                                                                                                                                                                                                                                                                                                                                                                                      | ARAUCA           | TAME                                                                                                                                                    | CAMPESINO               |                               65 |                     24 |                     41 |
# | 26 | 131-2022    | viable     |        48 |        14 | CAMPESINO-INDÍGENA      | PUEBLO BELLO                                                                                                                                            | CESAR            |           1 |                       0 |            1 |                 0 | 131-2022         | lavadoras, molino, nevera, congelador, estufa ecológica, mulos, guadaña, bicicletas, turbuna motobomba, fumigadora de motor                                                                                                                                                                                                                                                                                                                                                                                                       | CESAR            | PUEBLO BELLO                                                                                                                                            | CAMPESINO-INDÍGENA      |                               80 |                     20 |                     60 |
# | 27 | 1353-2023   | viable     |       103 |       102 | CAMPESINO               | ATACO                                                                                                                                                   | TOLIMA           |           1 |                       0 |            0 |                 0 | 1353-2023        | lavadoras, neveras, licuadoras, freidoras                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         | TOLIMA           | ATACO                                                                                                                                                   | CAMPESINO               |                               73 |                     20 |                     53 |
# | 28 | 258-2022    | viable     |       226 |       185 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 1 | 258-2022         | estufa ecoeficiente, mejoramiento unidad sanitaria                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                              103 |                     22 |                     81 |
# | 29 | 264-2022    | viable     |       150 |        45 | CAMPESINO               | COLOSÓ                                                                                                                                                  | SUCRE            |           1 |                       0 |            1 |                 0 | 264-2022         | nevera, congelador, licuadora, lavadora, estufa de gas, estufa eléctrica, estufa industrial, molino eléctrico, burros, motobomba,  tanque de almacenamiento de agua                                                                                                                                                                                                                                                                                                                                                               | SUCRE            | COLOSÓ                                                                                                                                                  | CAMPESINO               |                               65 |                     15 |                     50 |
# | 30 | 271-2022    | viable     |       107 |        71 | CAMPESINO               | CARTAGENA DEL CHAIRÁ                                                                                                                                    | CAQUETÁ          |           1 |                       0 |            0 |                 0 | 271-2022         | estufa ecoeficiente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | CAQUETÁ          | CARTAGENA DEL CHAIRÁ                                                                                                                                    | CAMPESINO               |                              178 |                     73 |                    105 |
# | 31 | 272-2022    | viable     |       198 |       134 | CAMPESINO               | ATACO, CHAPARRAL Y RIOBLANCO                                                                                                                            | TOLIMA           |           1 |                       0 |            0 |                 0 | 272-2022         | estufa ecoeficiente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | TOLIMA           | ATACO, CHAPARRAL Y RIOBLANCO                                                                                                                            | CAMPESINO               |                              100 |                     19 |                     81 |
# | 32 | 274-2022    | viable     |       611 |       320 | CAMPESINO               | SAN ONOFRE                                                                                                                                              | SUCRE            |           1 |                       0 |            1 |                 0 | 274-2022         | estufa, lavadora, nevera, licuadora, olla a presión, congelador, guadaña, motobomba, manguera, tanque almacenamiento agua                                                                                                                                                                                                                                                                                                                                                                                                         | SUCRE            | SAN ONOFRE                                                                                                                                              | CAMPESINO               |                              104 |                     43 |                     61 |
# | 33 | 277-2022    | viable     |       175 |       143 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 277-2022         | lavadoras, neveras                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                              121 |                     27 |                     94 |
# | 35 | 283-2022    | viable     |       153 |       106 | CAMPESINO               | SAN ANTONIO DE PALMITO                                                                                                                                  | SUCRE            |           0 |                       0 |            1 |                 0 | 283-2022         | electrobomba, manguera                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            | SUCRE            | SAN ANTONIO DE PALMITO                                                                                                                                  | CAMPESINO               |                              259 |                    159 |                    100 |
# | 36 | 285-2022    | viable     |        90 |        95 | CAMPESINO               | PUERTO CONCORDIA                                                                                                                                        | META             |           0 |                       0 |            1 |                 1 | 285-2022         | sistema de iluminación vivienda, sistema de captación de agua, sistema de cosecha de agua lluvia                                                                                                                                                                                                                                                                                                                                                                                                                                  | META             | PUERTO CONCORDIA                                                                                                                                        | CAMPESINO               |                              110 |                     38 |                     72 |
# | 37 | 286-2022    | viable     |        44 |        33 | CAMPESINO               | CARTAGENA DEL CHAIRÁ                                                                                                                                    | CAQUETÁ          |           1 |                       0 |            0 |                 0 | 286-2022         | estufa ecoeficiente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | CAQUETÁ          | CARTAGENA DEL CHAIRÁ                                                                                                                                    | CAMPESINO               |                               77 |                     35 |                     42 |
# | 38 | 289-2022    | viable     |       145 |       142 | CAMPESINO               | ALBANIA                                                                                                                                                 | CAQUETÁ          |           1 |                       0 |            1 |                 0 | 289-2022         | estufa ecoeficiente, lavadoras, refrigeradores, motobomba con accesorios, tanque de agua                                                                                                                                                                                                                                                                                                                                                                                                                                          | CAQUETÁ          | ALBANIA                                                                                                                                                 | CAMPESINO               |                               69 |                     17 |                     52 |
# | 39 | 291-2022    | viable     |       128 |       177 | CAMPESINO               | CHAPARRAL                                                                                                                                               | TOLIMA           |           1 |                       0 |            0 |                 0 | 291-2022         | estufa ecoeficiente, lavadora, nevera, estufa a gas, mueble de alacena con lavaplatos                                                                                                                                                                                                                                                                                                                                                                                                                                             | TOLIMA           | CHAPARRAL                                                                                                                                               | CAMPESINO               |                               76 |                     41 |                     35 |
# | 41 | 295-2022    | viable     |       120 |       100 | CAMPESINO-INDÍGENA      | VALENCIA                                                                                                                                                | CÓRDOBA          |           1 |                       1 |            1 |                 1 | 295-2022         | Silla de ruedas, estufa ecoeficiente y adecuación de espacio para su instalación, guadaña, adecuación y dotación espacio para actividades de formación y recreativas, tanques agua                                                                                                                                                                                                                                                                                                                                                | CÓRDOBA          | VALENCIA                                                                                                                                                | CAMPESINO-INDÍGENA      |                              149 |                     59 |                     90 |
# | 43 | 301-2022    | viable     |       440 |       660 | CAMPESINO               | EL TAMBO                                                                                                                                                | CAUCA            |           1 |                       0 |            1 |                 0 | 301-2022         | Lavadoras, tanque agua, electrobomba, filtro agua, congelador, guadaña, nevera                                                                                                                                                                                                                                                                                                                                                                                                                                                    | CAUCA            | EL TAMBO                                                                                                                                                | CAMPESINO               |                              220 |                    170 |                     50 |
# | 44 | 304-2022    | viable     |        83 |        60 | CAMPESINO               | MERCADERES Y BALBOA                                                                                                                                     | CAUCA            |           1 |                       0 |            0 |                 0 | 304-2022         | Lavadora, nevera                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  | CAUCA            | MERCADERES Y BALBOA                                                                                                                                     | CAMPESINO               |                              143 |                     59 |                     84 |
# | 46 | 324-2022    | viable     |       115 |        95 | CAMPESINO-INDÍGENA-NARP | MORALES                                                                                                                                                 | CAUCA            |           1 |                       1 |            0 |                 0 | 324-2022         | estufa con horno, estufa de empotrar, estufa eléctrica, lavadora, nevera, horno industrial, freidora, olla arrocera, olla presión, licuadora, molino con motor, juego de ollas, silla de ruedas, campana extractora de humo, motobomba, estacionaria, manguera, picadora, panel solar, adecuación de sitio para cosecha de agua en laboratorio de calidades, cocina integral, reposición de cubierta                                                                                                                              | CAUCA            | MORALES                                                                                                                                                 | CAMPESINO-INDÍGENA-NARP |                               86 |                     26 |                     60 |
# ...
# | 67 | 779-2020    | viable     |       193 |       177 | NARP                    | SANTA ROSA DEL SUR                                                                                                                                      | BOLÍVAR          |           1 |                       1 |            1 |                 0 | 779-2020         | Estufas ecológicas o ecoeficientes, Molino eléctrico con motor 1hp 110V, tolva en acero , Horno a gas, refrigerador, congelador horizontal, lavadora, silla de ruedas, sistema fotovoltáico, batería panel solar                                                                                                                                                                                                                                                                                                                  | BOLÍVAR          | SANTA ROSA DEL SUR                                                                                                                                      | NARP                    |                              121 |                     59 |                     62 |
# | 68 | 780-2020    | viable     |        22 |        26 | INDÍGENA                | FLORENCIA                                                                                                                                               | CAQUETÁ          |           1 |                       1 |            1 |                 1 | 780-2020         | Lavadora, nevera, congelador, refrigerador, molino eléctrico, licuadora, audífonos, estufa ecoeficiente, panel solar, electrobomba slar, motocarguero, jiffyt pellets, adecuación baños secos, planta solar                                                                                                                                                                                                                                                                                                                       | CAQUETÁ          | FLORENCIA                                                                                                                                               | INDÍGENA                |                               65 |                     27 |                     38 |
# | 69 | 781-2020    | viable     |       190 |        75 | INDÍGENA                | CAJIBÍO                                                                                                                                                 | CAUCA            |           1 |                       0 |            0 |                 0 | 781-2020         | nevera no frost, estufa con horno, lavadora, horno para pan, olla arrocera, licuadora, molino eléctrico, batería de ollas, motobomba sumergible, estacionaria con manguera, tanque agua                                                                                                                                                                                                                                                                                                                                           | CAUCA            | CAJIBÍO                                                                                                                                                 | INDÍGENA                |                               85 |                     22 |                     63 |
# | 70 | 783-2020    | viable     |       277 |       208 | CAMPESINO               | EL ROSARIO                                                                                                                                              | NARIÑO           |           1 |                       0 |            1 |                 0 | 783-2020         | freidora de aire, lavadora, gallinas ponedoras, kit semillas hortalizas                                                                                                                                                                                                                                                                                                                                                                                                                                                           | NARIÑO           | EL ROSARIO                                                                                                                                              | CAMPESINO               |                               99 |                     41 |                     58 |
# | 71 | 784-2020    | viable     |       155 |       200 | INDÍGENA                | EL PAUJIL                                                                                                                                               | CAQUETÁ          |           1 |                       0 |            0 |                 0 | 784-2020         | Lavadora, nevera, licuadora                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       | CAQUETÁ          | EL PAUJIL                                                                                                                                               | INDÍGENA                |                               71 |                     71 |                      0 |
# | 72 | 787-2020    | viable     |        52 |        32 | INDÍGENA-NARP           | SAN VICENTE DEL CAGUÁN                                                                                                                                  | CAQUETÁ          |           1 |                       0 |            0 |                 0 | 787-2020         | Lavadora                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          | CAQUETÁ          | SAN VICENTE DEL CAGUÁN                                                                                                                                  | INDÍGENA-NARP           |                              120 |                     55 |                     65 |
# | 73 | 789-2020    | viable     |       110 |        65 | CAMPESINO               | CARTAGENA DEL CHAIRÁ                                                                                                                                    | CAQUETÁ          |           1 |                       0 |            0 |                 0 | 789-2020         | Estufa ecoeficiente                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               | CAQUETÁ          | CARTAGENA DEL CHAIRÁ                                                                                                                                    | CAMPESINO               |                              106 |                     58 |                     48 |
# | 74 | 795-2020    | viable     |       228 |       218 | INDÍGENA                | EL TAMBO-CAJIBÍO                                                                                                                                        | CAUCA            |           1 |                       0 |            0 |                 0 | 795-2020         | estufas ecoeficientes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             | CAUCA            | EL TAMBO-CAJIBÍO                                                                                                                                        | INDÍGENA                |                              137 |                     72 |                     65 |
# | 75 | 854-2020    | viable     |        99 |       131 | CAMPESINO               | TUMACO                                                                                                                                                  | NARIÑO           |           1 |                       0 |            0 |                 0 | 854-2020         | estufa de piso a gas, cilindro, lavadora, tanque de agua, regulador de energía, nevera, congelador horizontal                                                                                                                                                                                                                                                                                                                                                                                                                     | NARIÑO           | TUMACO                                                                                                                                                  | CAMPESINO               |                               65 |                     65 |                      0 |
# | 76 | 860-2020    | viable     |       170 |       130 | CAMPESINO-INDÍGENA      | SAN ANTONIO DE PALMITO                                                                                                                                  | SUCRE            |           1 |                       0 |            1 |                 0 | 860-2020         | Congelador, nevera, licuadora, lavadora, estufas a gas, tanque de agua, motobomba                                                                                                                                                                                                                                                                                                                                                                                                                                                 | SUCRE            | SAN ANTONIO DE PALMITO                                                                                                                                  | CAMPESINO-INDÍGENA      |                              100 |                     42 |                     58 |
# | 77 | 861-2020    | viable     |       287 |       341 | CAMPESINO-INDÍGENA-NARP | TUMACO                                                                                                                                                  | NARIÑO           |           1 |                       0 |            1 |                 0 | 861-2020         | estufas a gas, cilindro, congeladores, neveras, baterías de cocina, vajillas, licuadoras, ollas arroceras, pitadoras, lavadoras con accesorios, tanque de agua, bombas de motor, panel solar, electrobombas, inversor de energía, batería para energía, cama doble con colchón semiortopédico                                                                                                                                                                                                                                     | NARIÑO           | TUMACO                                                                                                                                                  | CAMPESINO-INDÍGENA-NARP |                              500 |                    193 |                    307 |
# | 78 | 923-2020    | viable     |        85 |       121 | CAMPESINO               | EL BAGRE, ZARAGOZA, NECHI Y CAUCASIA                                                                                                                    | ANTIOQUIA        |           1 |                       1 |            1 |                 1 | 923-2020         | estufa ecoeficiente, estufa de gas, nevera, bastón, silla de ruedas, licuadora, estibas, lona para estufas, motocarro, dotación espacio de cuidado para niños, niñas y adolescentes, adecuación cocina comunitaria, dotación cocina doméstica, estufa ecoeficiente híbrida, horno microondas                                                                                                                                                                                                                                      | ANTIOQUIA        | EL BAGRE, ZARAGOZA, NECHI Y CAUCASIA                                                                                                                    | CAMPESINO               |                              206 |                    112 |                     94 |
# +----+-------------+------------+-----------+-----------+-------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+-------------+-------------------------+--------------+-------------------+------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+----------------------------------+------------------------+------------------------+

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# Merge the shapefile with the project data
merged_data = dpto_shapefile.merge(py_ini, left_on='NAME_1', right_on='Departamento')

# Convert to Web Mercator projection (EPSG:3857) for compatibility with contextily
merged_data = merged_data.to_crs(epsg=3857)

# Plot the map with TotalBeneficiariosDepartamento
fig, ax = plt.subplots(1, 1, figsize=(15, 15))
merged_data.plot(column='TotalBeneficiariosDepartamento', ax=ax, legend=True,
                 legend_kwds={'label': "Total Beneficiaries by Department",
                              'orientation': "horizontal"})

# Add background map
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)


plt.title('Total Beneficiaries by Department')
plt.show()

# %%
# Plot the distribution of MujeresBeneficiarias
plt.figure(figsize=(10, 6))
sns.histplot(py_ini['MujeresBeneficiarias'], kde=True, color='blue')
plt.title('Distribution of Mujeres Beneficiarias')
plt.xlabel('Mujeres Beneficiarias')
plt.ylabel('Frequency')
plt.show()

# Display the summary statistics of MujeresBeneficiarias
summary_stats_mujeres = py_ini['MujeresBeneficiarias'].describe()
print(summary_stats_mujeres)
# Out:
# count      87.000000
# mean       74.149425
# std       157.135368
# min         9.000000
# 25%        22.500000
# 50%        38.000000
# 75%        63.000000
# max      1179.000000
# Name: MujeresBeneficiarias, dtype: float64

# %%
# Create a new column 'Women_Below_10' with value 1 when the number of women is below 10, otherwise 0
viable_merged_proposals['Women_Below_10'] = viable_merged_proposals['MujeresBeneficiarias'].apply(lambda x: 1 if x < 30 else 0)

# Display the updated dataframe
print(viable_merged_proposals[['MujeresBeneficiarias', 'Women_Below_10']])
# Out:
#     MujeresBeneficiarias  Women_Below_10
# 0                     12               1
# 1                     36               0
# 2                     19               1
# 3                     62               0
# 4                     28               1
# ..                   ...             ...
# 74                    72               0
# 75                    65               0
# 76                    42               0
# 77                   193               0
# 78                   112               0
#
# [64 rows x 2 columns]
# /var/folders/dv/3wtcrb9s03n5nj64bl19r6qjqcgl9l/T/ipykernel_12930/2022986385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   viable_merged_proposals['Women_Below_10'] = viable_merged_proposals['MujeresBeneficiarias'].apply(lambda x: 1 if x < 30 else 0)

# %%
# Create a crosstabulate table with poblacion and Women_Below_10
crosstab_table = pd.crosstab(viable_merged_proposals['poblacion'], viable_merged_proposals['Women_Below_10'])

# Display the crosstabulate table
print(crosstab_table)
# Out:
# Women_Below_10            0   1
# poblacion
# CAMPESINO                23  23
# CAMPESINO-INDÍGENA        2   3
# CAMPESINO-INDÍGENA-NARP   2   2
# CAMPESINO-NARP            2   0
# INDÍGENA                  3   2
# INDÍGENA-NARP             1   0
# NARP                      1   0

# %%
# Filter the dataset
filtered_viable_proposals = viable_merged_proposals[(viable_merged_proposals['concepto'] == 'viable') & (viable_merged_proposals['Women_Below_10'] == 0)]

# Tabulate the 'poblacion' column
poblacion_tabulated = filtered_viable_proposals['poblacion'].value_counts().reset_index()
poblacion_tabulated.columns = ['poblacion', 'count']

# Display the tabulated data
print(poblacion_tabulated)
# Out:
#                  poblacion  count
# 0                CAMPESINO     23
# 1                 INDÍGENA      3
# 2           CAMPESINO-NARP      2
# 3  CAMPESINO-INDÍGENA-NARP      2
# 4       CAMPESINO-INDÍGENA      2
# 5                     NARP      1
# 6         INDÍGENA-NARP         1

# %%
# Generate summary statistics for MujeresBeneficiarias
summary_stats_mujeres = py_ini['MujeresBeneficiarias'].describe()

# Display the summary statistics
print(summary_stats_mujeres)
# Out:
# count      87.000000
# mean       74.149425
# std       157.135368
# min         9.000000
# 25%        22.500000
# 50%        38.000000
# 75%        63.000000
# max      1179.000000
# Name: MujeresBeneficiarias, dtype: float64

# %%
total_mujeres_beneficiarias = py_ini['MujeresBeneficiarias'].sum()
print(f"Total Mujeres Beneficiarias: {total_mujeres_beneficiarias}")
# Out:
# Total Mujeres Beneficiarias: 6451
